# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# %%
img = io.imread('F16.tiff')
img2= io.imread('lena.png')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (124, 152, 4)

# %%
plt.imshow(img2)

# %%
hist=plt.hist(img.ravel(),bins=256)
hist=plt.hist(img2.ravel(),bins=256)

# %%
pixels, bins=np.histogram(img,bins=256)

bins=bins[1:]

bins=bins.astype(np.int32)
pixels=pixels.astype(np.int32)

probability=pixels/np.sum(pixels)

# %%
cumulative=list()
sum_all=0

for i in range(256):
    sum_all=sum_all+probability[i]
    cumulative.append(sum_all)

cumulative=np.array(cumulative)

new=cumulative*255

# %%
new=new.astype(np.int32)

# %%
k=plt.hist(new,bins=256)

# %%
pixels2, bins2=np.histogram(img2,bins=256)

bins2=bins2[1:]

bins2=bins2.astype(np.int32)
pixels2=pixels2.astype(np.int32)

probability2=pixels2/np.sum(pixels2)

# %%
cumulative2=list()
sum_all2=0

for i in range(256):
    sum_all2=sum_all2+probability2[i]
    cumulative2.append(sum_all2)

cumulative2=np.array(cumulative2)

new2=cumulative2*255

# %%
new2=new2.astype(np.int32)

# %%
k=plt.hist(new2,bins=256)

# %%
for i in range(256):
    if(new[i] in new2):
            for j in range(256):
                if(new2[j]==new[i]):
                    new[i]=j
    else:
        minx=abs(new[i]-new2[0])
        for j in range(256):
            if(abs(new[i]-new2[j])<minx):
                minx=abs(new[i]-new2[j])
                new[i]=j

# %%
np.sum(new)
# Out:
# 28290

# %%
img.shape
# Out:
# (124, 152, 4)

# %%
m=plt.hist(new,bins=256)

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# %%
img = io.imread('F16.tiff')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (124, 152, 4)

# %%
hist=plt.hist(img.ravel(),bins=256)

# %%
values, bins=np.histogram(img,bins=256)

# %%
bins=bins[1:]

# %%
? np.histogram

# %%
bins=bins.astype(np.int32)
values=values.astype(np.int32)

# %%
bins.shape
# Out:
# (256,)

# %%
normed=values/np.sum(values)

# %%
cumulative=list()
sum_all=0

# %%
for i in range(256):
    sum_all=sum_all+normed[i]
    cumulative.append(sum_all)

# %%
cumulative=np.array(cumulative)

# %%
new=cumulative*255

# %%
new=new.astype(np.int32)

# %%
hist=plt.hist(img.ravel(),bins=256)

# %%
k=plt.hist(new,bins=256)

# %%
image=list()

# %%
for i in range(256):
    for j in range(new[i]+1):
        image.append(i)

# %%
image=np.array(image)

# %%
image.shape
# Out:
# (14307,)

# %%
img2=image.reshape((124, 152, 4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-18e3811a07e1> in <module>()
# ----> 1 img2=image.reshape((124, 152, 4))
#
# ValueError: cannot reshape array of size 14307 into shape (124,152,4)

# %%
124*154*4
# Out:
# 76384
